# %% [markdown]
# # NASA's archive on Exo-planets.  Part 1 - Data Collection

# %%
#start by getting the data from NASA's exoplanet-archive

import pandas as pd
import json
import requests

# %%
#url do get data

url ="https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+*+from+pscomppars&format=json"

# %%
r = requests.get(url)

# %%
#get data in json format
r_json=  r.json()

# %%
#slice data to see what is looks like
r_json[0]
# Out:
# {'pl_name': 'OGLE-2016-BLG-1227L b',
#  'pl_letter': 'b',
#  'hostname': 'OGLE-2016-BLG-1227L',
#  'hd_name': None,
#  'hip_name': None,
#  'tic_id': None,
#  'disc_pubdate': '2020-03',
#  'disc_year': 2020,
#  'discoverymethod': 'Microlensing',
#  'disc_locale': 'Ground',
#  'disc_facility': 'OGLE',
#  'disc_instrument': 'OGLE CCD Array',
#  'disc_telescope': '1.3 m Warsaw University Telescope',
#  'disc_refname': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'ra': 265.597125,
#  'rastr': '17h42m23.31s',
#  'dec': -33.7597778,
#  'decstr': '-33d45m35.2s',
#  'glon': 355.52875,
#  'glat': -1.93858,
#  'elon': 266.27974,
#  'elat': -10.37734,
#  'ra_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'pl_orbper': None,
#  'pl_orbpererr1': None,
#  'pl_orbpererr2': None,
#  'pl_orbperlim': None,
#  'pl_orbperstr': None,
#  'pl_orbper_reflink': None,
#  'pl_orblpererr1': None,
#  'pl_orblper': None,
#  'pl_orblpererr2': None,
#  'pl_orblperlim': None,
#  'pl_orblperstr': None,
#  'pl_orblper_reflink': None,
#  'pl_orbsmax': 3.4,
#  'pl_orbsmaxerr1': 2.1,
#  'pl_orbsmaxerr2': -1.0,
#  'pl_orbsmaxlim': 0,
#  'pl_orbsmaxstr': '<div><span class="supersubNumber">3.4</span> <span class="superscript">+2.1</span><span class="subscript">-1.0</span> </div>',
#  'pl_orbsmax_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'pl_orbincl': None,
#  'pl_orbinclerr1': None,
#  'pl_orbinclerr2': None,
#  'pl_orbincllim': None,
#  'pl_orbinclstr': None,
#  'pl_orbincl_reflink': None,
#  'pl_orbtper': None,
#  'pl_orbtpererr1': None,
#  'pl_orbtpererr2': None,
#  'pl_orbtperlim': None,
#  'pl_orbtperstr': None,
#  'pl_orbtper_reflink': None,
#  'pl_orbeccen': None,
#  'pl_orbeccenerr1': None,
#  'pl_orbeccenerr2': None,
#  'pl_orbeccenlim': None,
#  'pl_orbeccenstr': None,
#  'pl_orbeccen_reflink': None,
#  'pl_eqt': None,
#  'pl_eqterr1': None,
#  'pl_eqterr2': None,
#  'pl_eqtlim': None,
#  'pl_eqtstr': None,
#  'pl_eqt_reflink': None,
#  'pl_occdep': None,
#  'pl_occdeperr1': None,
#  'pl_occdeperr2': None,
#  'pl_occdeplim': None,
#  'pl_occdepstr': None,
#  'pl_occdep_reflink': None,
#  'pl_insol': None,
#  'pl_insolerr1': None,
#  'pl_insolerr2': None,
#  'pl_insollim': None,
#  'pl_insolstr': None,
#  'pl_insol_reflink': None,
#  'pl_dens': 0.512,
#  'pl_denserr1': None,
#  'pl_denserr2': None,
#  'pl_denslim': 0,
#  'pl_densstr': '0.512',
#  'pl_dens_reflink': '<a refstr=CALCULATED_VALUE href=/docs/composite_calc.html target=_blank>Calculated Value</a>',
#  'pl_trandep': None,
#  'pl_trandeperr1': None,
#  'pl_trandeperr2': None,
#  'pl_trandeplim': None,
#  'pl_trandepstr': None,
#  'pl_trandep_reflink': None,
#  'pl_tranmid': None,
#  'pl_tranmiderr1': None,
#  'pl_tranmiderr2': None,
#  'pl_tranmidlim': None,
#  'pl_tranmidstr': None,
#  'sy_pmdec': None,
#  'sy_pmdecerr1': None,
#  'sy_pmdecerr2': None,
#  'sy_pmdecstr': None,
#  'sy_plx': None,
#  'sy_plxerr1': None,
#  'sy_plxerr2': None,
#  'sy_plxstr': None,
#  'sy_plx_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_dist': None,
#  'sy_disterr1': None,
#  'sy_disterr2': None,
#  'sy_diststr': None,
#  'sy_dist_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_bmag': None,
#  'sy_bmagerr1': None,
#  'sy_bmagerr2': None,
#  'sy_bmagstr': None,
#  'sy_bmag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_vmag': None,
#  'sy_vmagerr1': None,
#  'sy_vmagerr2': None,
#  'sy_vmagstr': None,
#  'sy_vmag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_jmag': None,
#  'sy_jmagerr1': None,
#  'sy_jmagerr2': None,
#  'sy_jmagstr': None,
#  'sy_jmag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_hmag': None,
#  'sy_hmagerr1': None,
#  'sy_hmagerr2': None,
#  'sy_hmagstr': None,
#  'sy_hmag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_kmag': None,
#  'sy_kmagerr1': None,
#  'sy_kmagerr2': None,
#  'sy_kmagstr': None,
#  'sy_kmag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_umag': None,
#  'sy_umagerr1': None,
#  'sy_umagerr2': None,
#  'sy_umagstr': None,
#  'sy_umag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_rmag': None,
#  'sy_rmagerr1': None,
#  'sy_rmagerr2': None,
#  'sy_rmagstr': None,
#  'sy_rmag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_imag': None,
#  'sy_imagerr1': None,
#  'sy_imagerr2': None,
#  'sy_imagstr': None,
#  'sy_imag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_zmag': None,
#  'sy_zmagerr1': None,
#  'sy_zmagerr2': None,
#  'sy_zmagstr': None,
#  'sy_zmag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_w1mag': None,
#  'sy_w1magerr1': None,
#  'sy_w1magerr2': None,
#  'sy_w1magstr': None,
#  'sy_w1mag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_w2mag': None,
#  'sy_w2magerr1': None,
#  'sy_w2magerr2': None,
#  'sy_w2magstr': None,
#  'sy_w2mag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_w3mag': None,
#  'sy_w3magerr1': None,
#  'sy_w3magerr2': None,
#  'sy_w3magstr': None,
#  'sy_w3mag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_w4mag': None,
#  'sy_w4magerr1': None,
#  'sy_w4magerr2': None,
#  'sy_w4magstr': None,
#  'sy_w4mag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_gmag': None,
#  'sy_gmagerr1': None,
#  'sy_gmagerr2': None,
#  'sy_gmagstr': None,
#  'sy_gmag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_gaiamag': None,
#  'sy_gaiamagerr1': None,
#  'sy_gaiamagerr2': None,
#  'sy_gaiamagstr': None,
#  'sy_gaiamag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_tmag': None,
#  'sy_tmagerr1': None,
#  'sy_tmagerr2': None,
#  'sy_tmagstr': None,
#  'sy_tmag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'pl_controv_flag': 0,
#  'pl_orbtper_systemref': None,
#  'pl_tranmid_systemref': None,
#  'st_metratio': None,
#  'st_spectype': None,
#  'st_spectype_reflink': None,
#  'sy_kepmag': None,
#  'sy_kepmagerr1': None,
#  'sy_kepmagerr2': None,
#  'sy_kepmagstr': None,
#  'sy_kepmag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'st_rotp': None,
#  'st_rotperr1': None,
#  'st_rotperr2': None,
#  'st_rotplim': None,
#  'st_rotpstr': None,
#  'st_rotp_reflink': None,
#  'pl_projobliq': None,
#  'pl_projobliqerr1': None,
#  'pl_projobliqerr2': None,
#  'pl_projobliqlim': None,
#  'pl_projobliqstr': None,
#  'pl_projobliq_reflink': None,
#  'gaia_id': None,
#  'cb_flag': 0,
#  'pl_tranmid_reflink': None,
#  'pl_trandur': None,
#  'pl_trandurerr1': None,
#  'pl_trandurerr2': None,
#  'pl_trandurlim': None,
#  'pl_trandurstr': None,
#  'pl_trandur_reflink': None,
#  'pl_rvamp': None,
#  'pl_rvamperr1': None,
#  'pl_rvamperr2': None,
#  'pl_rvamplim': None,
#  'pl_rvampstr': None,
#  'pl_rvamp_reflink': None,
#  'pl_radj': 1.24,
#  'pl_radjerr1': None,
#  'pl_radjerr2': None,
#  'pl_radjlim': 0,
#  'pl_radjstr': '1.24',
#  'pl_radj_reflink': '<a refstr=CALCULATED_VALUE href=/docs/composite_calc.html target=_blank>Calculated Value</a>',
#  'pl_rade': 13.9,
#  'pl_radeerr1': None,
#  'pl_radeerr2': None,
#  'pl_radelim': 0,
#  'pl_radestr': '13.9',
#  'pl_rade_reflink': '<a refstr=CALCULATED_VALUE href=/docs/composite_calc.html target=_blank>Calculated Value</a>',
#  'pl_ratror': None,
#  'pl_ratrorerr1': None,
#  'pl_ratrorerr2': None,
#  'pl_ratrorlim': None,
#  'pl_ratrorstr': None,
#  'pl_ratror_reflink': None,
#  'pl_ratdor': None,
#  'pl_trueobliq': None,
#  'pl_trueobliqerr1': None,
#  'pl_trueobliqerr2': None,
#  'pl_trueobliqlim': None,
#  'pl_trueobliqstr': None,
#  'pl_trueobliq_reflink': None,
#  'sy_icmag': None,
#  'sy_icmagerr1': None,
#  'sy_icmagerr2': None,
#  'sy_icmagstr': None,
#  'sy_icmag_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'dkin_flag': 0,
#  'pl_ratdorerr1': None,
#  'pl_ratdorerr2': None,
#  'pl_ratdorlim': None,
#  'pl_ratdorstr': None,
#  'pl_ratdor_reflink': None,
#  'pl_imppar': None,
#  'pl_impparerr1': None,
#  'pl_impparerr2': None,
#  'pl_impparlim': None,
#  'pl_impparstr': None,
#  'pl_imppar_reflink': None,
#  'pl_bmassj': 0.79,
#  'pl_bmassjerr1': 1.3,
#  'pl_bmassjerr2': -0.39,
#  'pl_bmassjlim': 0,
#  'pl_bmassjstr': '<div><span class="supersubNumber">0.79</span> <span class="superscript">+1.30</span><span class="subscript">-0.39</span> </div>',
#  'pl_bmassj_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'pl_bmasse': 250.0,
#  'pl_bmasseerr1': 413.0,
#  'pl_bmasseerr2': -120.0,
#  'pl_bmasselim': 0,
#  'pl_bmassestr': '<div><span class="supersubNumber">250</span> <span class="superscript">+413</span><span class="subscript">-120</span> </div>',
#  'pl_bmasse_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'pl_bmassprov': 'Mass',
#  'st_teff': None,
#  'st_tefferr1': None,
#  'st_tefferr2': None,
#  'st_tefflim': None,
#  'st_teffstr': None,
#  'st_teff_reflink': None,
#  'st_met': None,
#  'st_meterr1': None,
#  'st_meterr2': None,
#  'st_metlim': None,
#  'st_metstr': None,
#  'st_met_reflink': None,
#  'st_radv': None,
#  'st_radverr1': None,
#  'st_radverr2': None,
#  'st_radvlim': None,
#  'st_radvstr': None,
#  'st_radv_reflink': None,
#  'st_vsin': None,
#  'st_vsinerr1': None,
#  'st_vsinerr2': None,
#  'st_vsinlim': None,
#  'st_vsinstr': None,
#  'st_vsin_reflink': None,
#  'st_lum': None,
#  'st_lumerr1': None,
#  'st_lumerr2': None,
#  'st_lumlim': None,
#  'st_lumstr': None,
#  'st_lum_reflink': None,
#  'st_logg': None,
#  'st_loggerr1': None,
#  'st_loggerr2': None,
#  'st_logglim': None,
#  'st_loggstr': None,
#  'st_logg_reflink': None,
#  'st_age': None,
#  'st_ageerr1': None,
#  'st_ageerr2': None,
#  'st_agelim': None,
#  'st_agestr': None,
#  'st_age_reflink': None,
#  'st_mass': 0.1,
#  'st_masserr1': 0.17,
#  'st_masserr2': -0.05,
#  'st_masslim': 0,
#  'st_massstr': '<div><span class="supersubNumber">0.10</span> <span class="superscript">+0.17</span><span class="subscript">-0.05</span> </div>',
#  'st_mass_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'st_dens': None,
#  'st_denserr1': None,
#  'st_denserr2': None,
#  'st_denslim': None,
#  'st_densstr': None,
#  'st_dens_reflink': None,
#  'st_rad': None,
#  'st_raderr1': None,
#  'st_raderr2': None,
#  'st_radlim': None,
#  'st_radstr': None,
#  'st_rad_reflink': None,
#  'ttv_flag': 0,
#  'ptv_flag': 0,
#  'tran_flag': 0,
#  'rv_flag': 0,
#  'ast_flag': 0,
#  'obm_flag': 0,
#  'micro_flag': 1,
#  'etv_flag': 0,
#  'ima_flag': 0,
#  'pul_flag': 0,
#  'sy_snum': 1,
#  'sy_pnum': 1,
#  'sy_mnum': 0,
#  'st_nphot': 0,
#  'st_nrvc': 0,
#  'st_nspec': 0,
#  'pl_nespec': 0,
#  'pl_ntranspec': 0,
#  'pl_nnotes': 4,
#  'sy_pm': None,
#  'sy_pmerr1': None,
#  'sy_pmerr2': None,
#  'sy_pmstr': None,
#  'sy_pm_reflink': '<a refstr=HAN_ET_AL__2020 href=https://ui.adsabs.harvard.edu/abs/2020AJ....159...91H/abstract target=ref>Han et al. 2020</a>',
#  'sy_pmra': None,
#  'sy_pmraerr1': None,
#  'sy_pmraerr2': None,
#  'sy_pmrastr': None,
#  'x': -0.06382385973040276,
#  'y': -0.8289213204458156,
#  'z': -0.5557121192123485,
#  'htm20': -768415656}
